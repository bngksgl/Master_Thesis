# %%
import json 
import pandas as pd
import numpy as np
import uuid 
import rdflib
import collections

# %%
def nt_to_csv(path, source):
    # converts source and target files
    # load the .nt file
    g = rdflib.Graph()
    if source: 
        g.parse(path+'/source', format="nt")
    else:
        g.parse(path+'/target', format="nt")
    # put it into a dictionary
    phone_source = collections.defaultdict(dict)
    for s,p,o in g:
        phone_source[str(s)][str(p)] = str(o)

    phone_source = pd.DataFrame.from_dict(phone_source, orient='index')
    
    if source: # product pages
        d =[]
        for i in list(phone_source.index):
            d.append(i[24:])
        phone_source['page_id']=d
        phone_source=change_col_names(phone_source, 'page')
    else: # catalog
        d =[]
        for i in list(phone_source.index):
            d.append(i[28:])
        phone_source['catalog_id']=d
        phone_source=change_col_names(phone_source, 'cat')
    

    return phone_source

# %%
def change_col_names(df, prefix):
    # change column names of the dataframe and returns it
    result=[]
    for c in df.columns:
        if(c== 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'):
            result.append('page_type')
        elif(c == 'page_id'):
            result.append('page_id')
        elif (c== 'catalog_id'):
            result.append('catalog_id')
        else:
            result.append(prefix+'_'+c.split('http://schema.org/Product/')[1])
    df.columns=result
    return df

# %%
def get_goldstandard(correspondence_path):
    # 'GoldStandard/Correspondences/phonecorrespndences.csv'
    cor_phone=pd.read_csv(correspondence_path+'/correspondence.csv',sep=';',names=['id_webpage','catalog_id','match'],header=0)
    return cor_phone

# %%
def get_product_cat(correspondence_path):
    # gets the product catalog
    id_prodcat_info= pd.read_json(correspondence_path+'/product_catalog.json', encoding='utf-8')
    id_prodcat_info.columns=['prodcat_'+c for c in id_prodcat_info.columns]
    id_prodcat_info = id_prodcat_info[['prodcat_product_name','prodcat_id']]
    return id_prodcat_info

# %%
def merge(prod_cat,gold,target,source):
    # Merge step 1:
    # We need product catalog ids to merge with target, because the target doesn't have names and therefore cannnot 
    # be joined with the gold standard
    prod_cat=pd.merge(target, prod_cat, how='left', left_on='catalog_id',right_on='prodcat_id')
    # Merge step 2: Add web page columns and add it to the correspondences
    phone_getsource=pd.merge(gold, source, how='inner',left_on='id_webpage',right_on='page_id')
    # Merge step 3: Add product catalog columns and add it to the correspondences
    phone_result=pd.merge(phone_getsource, prod_cat, how='inner',left_on='catalog_id',right_on='prodcat_product_name')
    phone_result=phone_result.drop(['page_type_y','page_type_x','catalog_id_x','catalog_id_y','page_id'],axis=1)
    print('Product catalog shape (target):',target.shape)
    print('Product catalog after merging with extracted:',prod_cat.shape)
    print('Gold standard shape:',gold.shape)
    print('Product pages shape (source):',source.shape)
    print('Merge 1- web pages:',phone_getsource.shape)
    print('Merge 2- all:',phone_result.shape)
    print('Number of unique products from prodcat:',phone_result['prodcat_id'].nunique())
    print('Number of unique webpages:',phone_result['id_webpage'].nunique())
    print('Matches:')
    print(phone_result['match'].value_counts())
    return phone_result

# %%
def get_dataset(path):
    source_df=nt_to_csv(path, True)
    target_df=nt_to_csv(path, False)
    gold_df=get_goldstandard(path)
    prod_cat=get_product_cat(path)
    result=merge(prod_cat,gold_df,target_df,source_df)
    result=get_unique_ids(result)
    return result

# %%
def get_unique_ids(df):
    norows=df.shape[0]
    ids=[str(uuid.uuid1()) for i in range(0,norows)]
    df['id']=ids
    return df

# %% [markdown]
# # 1. Phones

# %%
phone_path ='/Users/bengikoseoglu/Documents/Masters/Semester4/Thesis/Dataset/Phone'
source_df=nt_to_csv(phone_path, True)
target_df=nt_to_csv(phone_path, False)

# %%
print(source_df.shape)
source_df.head()
# Out:
# (447, 29)
#                                                    page_brand  \
# http://dws.products.wdc/node031213ef8e26298cc43...    samsung
# http://dws.products.wdc/node0643f1b1f12ba371f0d...      apple
# http://dws.products.wdc/node06edc149e3ceee41df9...      apple
# http://dws.products.wdc/node0838278be7fc8b21449...     huawei
# http://dws.products.wdc/node0998e335ef295a25624...        htc
#
#                                                    page_rear_cam_resolution  \
# http://dws.products.wdc/node031213ef8e26298cc43...                    16 mp
# http://dws.products.wdc/node0643f1b1f12ba371f0d...                     8 mp
# http://dws.products.wdc/node06edc149e3ceee41df9...                     8 mp
# http://dws.products.wdc/node0838278be7fc8b21449...                      NaN
# http://dws.products.wdc/node0998e335ef295a25624...                     5 mp
#
#                                                           page_mpn  \
# http://dws.products.wdc/node031213ef8e26298cc43...        sm-g925a
# http://dws.products.wdc/node0643f1b1f12ba371f0d...       md636ll/a
# http://dws.products.wdc/node06edc149e3ceee41df9...  does not apply
# http://dws.products.wdc/node0838278be7fc8b21449...           h1512
# http://dws.products.wdc/node0998e335ef295a25624...             NaN
#
#                                                    page_computer_operating_system  \
# http://dws.products.wdc/node031213ef8e26298cc43...                        android
# http://dws.products.wdc/node0643f1b1f12ba371f0d...                            NaN
# http://dws.products.wdc/node06edc149e3ceee41df9...                            NaN
# http://dws.products.wdc/node0838278be7fc8b21449...                        android
# http://dws.products.wdc/node0998e335ef295a25624...                            NaN
#
#                                                    page_memory  \
# http://dws.products.wdc/node031213ef8e26298cc43...        32gb
# http://dws.products.wdc/node0643f1b1f12ba371f0d...        32gb
# http://dws.products.wdc/node06edc149e3ceee41df9...         8gb
# http://dws.products.wdc/node0838278be7fc8b21449...        64gb
# http://dws.products.wdc/node0998e335ef295a25624...         NaN
#
#                                                    page_phone_type  \
# http://dws.products.wdc/node031213ef8e26298cc43...  galaxy s6 edge
# http://dws.products.wdc/node0643f1b1f12ba371f0d...        iphone 5
# http://dws.products.wdc/node06edc149e3ceee41df9...       iphone 4s
# http://dws.products.wdc/node0838278be7fc8b21449...        nexus 6p
# http://dws.products.wdc/node0998e335ef295a25624...          one m8
#
#                                                    page_display_size  \
# http://dws.products.wdc/node031213ef8e26298cc43...            5.1 in
# http://dws.products.wdc/node0643f1b1f12ba371f0d...              4 in
# http://dws.products.wdc/node06edc149e3ceee41df9...            3.5 in
# http://dws.products.wdc/node0838278be7fc8b21449...            5.7 in
# http://dws.products.wdc/node0998e335ef295a25624...              5 in
#
#                                                                     page_type  \
# http://dws.products.wdc/node031213ef8e26298cc43...  http://schema.org/Product
# http://dws.products.wdc/node0643f1b1f12ba371f0d...  http://schema.org/Product
# http://dws.products.wdc/node06edc149e3ceee41df9...  http://schema.org/Product
# http://dws.products.wdc/node0838278be7fc8b21449...  http://schema.org/Product
# http://dws.products.wdc/node0998e335ef295a25624...  http://schema.org/Product
#
#                                                                page_warc  \
# http://dws.products.wdc/node031213ef8e26298cc43...  ebay.com0.warc.nq.gz
# http://dws.products.wdc/node0643f1b1f12ba371f0d...  ebay.com1.warc.nq.gz
# http://dws.products.wdc/node06edc149e3ceee41df9...  ebay.com0.warc.nq.gz
# http://dws.products.wdc/node0838278be7fc8b21449...  ebay.com0.warc.nq.gz
# http://dws.products.wdc/node0998e335ef295a25624...  ebay.com0.warc.nq.gz
#
#                                                                                              page_url  \
# http://dws.products.wdc/node031213ef8e26298cc43...  http://www.ebay.com/itm/samsung-galaxy-s6-edge...
# http://dws.products.wdc/node0643f1b1f12ba371f0d...  http://www.ebay.com/itm/apple-iphone-5-32gb-bl...
# http://dws.products.wdc/node06edc149e3ceee41df9...  http://www.ebay.com/itm/iphone-4s-8gb-white-fa...
# http://dws.products.wdc/node0838278be7fc8b21449...  http://www.ebay.com/itm/huawei-google-nexus-6p...
# http://dws.products.wdc/node0998e335ef295a25624...  http://www.ebay.com/itm/htc-one-m8-latest-mode...
#
#                                                                    ...                   \
# http://dws.products.wdc/node031213ef8e26298cc43...                 ...
# http://dws.products.wdc/node0643f1b1f12ba371f0d...                 ...
# http://dws.products.wdc/node06edc149e3ceee41df9...                 ...
# http://dws.products.wdc/node0838278be7fc8b21449...                 ...
# http://dws.products.wdc/node0998e335ef295a25624...                 ...
#
#                                                    page_product_type  \
# http://dws.products.wdc/node031213ef8e26298cc43...               NaN
# http://dws.products.wdc/node0643f1b1f12ba371f0d...        smartphone
# http://dws.products.wdc/node06edc149e3ceee41df9...               NaN
# http://dws.products.wdc/node0838278be7fc8b21449...               NaN
# http://dws.products.wdc/node0998e335ef295a25624...               NaN
#
#                                                    page_phone_carrier  \
# http://dws.products.wdc/node031213ef8e26298cc43...                NaN
# http://dws.products.wdc/node0643f1b1f12ba371f0d...               at&t
# http://dws.products.wdc/node06edc149e3ceee41df9...                NaN
# http://dws.products.wdc/node0838278be7fc8b21449...                NaN
# http://dws.products.wdc/node0998e335ef295a25624...                NaN
#
#                                                            page_processor_type  \
# http://dws.products.wdc/node031213ef8e26298cc43...                         NaN
# http://dws.products.wdc/node0643f1b1f12ba371f0d...                         NaN
# http://dws.products.wdc/node06edc149e3ceee41df9...                   dual core
# http://dws.products.wdc/node0838278be7fc8b21449...  aluminium, graphite, frost
# http://dws.products.wdc/node0998e335ef295a25624...                         NaN
#
#                                                    page_front_cam_resolution  \
# http://dws.products.wdc/node031213ef8e26298cc43...                       NaN
# http://dws.products.wdc/node0643f1b1f12ba371f0d...                       NaN
# http://dws.products.wdc/node06edc149e3ceee41df9...                       NaN
# http://dws.products.wdc/node0838278be7fc8b21449...                       NaN
# http://dws.products.wdc/node0998e335ef295a25624...                       NaN
#
#                                                    page_ram page_dimensions  \
# http://dws.products.wdc/node031213ef8e26298cc43...      NaN             NaN
# http://dws.products.wdc/node0643f1b1f12ba371f0d...      NaN             NaN
# http://dws.products.wdc/node06edc149e3ceee41df9...      NaN             NaN
# http://dws.products.wdc/node0838278be7fc8b21449...      NaN             NaN
# http://dws.products.wdc/node0998e335ef295a25624...      NaN             NaN
#
#                                                    page_manufacturer  \
# http://dws.products.wdc/node031213ef8e26298cc43...               NaN
# http://dws.products.wdc/node0643f1b1f12ba371f0d...               NaN
# http://dws.products.wdc/node06edc149e3ceee41df9...               NaN
# http://dws.products.wdc/node0838278be7fc8b21449...               NaN
# http://dws.products.wdc/node0998e335ef295a25624...               NaN
#
#                                                    page_modelnum  \
# http://dws.products.wdc/node031213ef8e26298cc43...           NaN
# http://dws.products.wdc/node0643f1b1f12ba371f0d...           NaN
# http://dws.products.wdc/node06edc149e3ceee41df9...           NaN
# http://dws.products.wdc/node0838278be7fc8b21449...           NaN
# http://dws.products.wdc/node0998e335ef295a25624...           NaN
#
#                                                    page_body_material  \
# http://dws.products.wdc/node031213ef8e26298cc43...                NaN
# http://dws.products.wdc/node0643f1b1f12ba371f0d...                NaN
# http://dws.products.wdc/node06edc149e3ceee41df9...                NaN
# http://dws.products.wdc/node0838278be7fc8b21449...                NaN
# http://dws.products.wdc/node0998e335ef295a25624...                NaN
#
#                                                                                 page_id
# http://dws.products.wdc/node031213ef8e26298cc43...  node031213ef8e26298cc43dd6282ead2a3
# http://dws.products.wdc/node0643f1b1f12ba371f0d...    node0643f1b1f12ba371f0d1fc4c9645e
# http://dws.products.wdc/node06edc149e3ceee41df9...    node06edc149e3ceee41df94b232bcb80
# http://dws.products.wdc/node0838278be7fc8b21449...  node0838278be7fc8b21449e123b6effce6
# http://dws.products.wdc/node0998e335ef295a25624...   node0998e335ef295a25624b8ca3a591d1
#
# [5 rows x 29 columns]

# %%
print(target_df.shape)
target_df.head()
# Out:
# (50, 31)
#                                                                                               cat_mpn  \
# http://dws.products.catalog/06b3b853-5246-4717-...  iphone532gbblackatt, md636ll/a, e63umtjxt1, ip...
# http://dws.products.catalog/0bfe4eac-5a9c-4bb0-...
# http://dws.products.catalog/0fd9d78a-1ed6-4ed9-...                                me299e/a, me299ll/a
# http://dws.products.catalog/110d9912-96fd-4b0c-...                                          mgcn2ll/a
# http://dws.products.catalog/15ff8065-eb3b-4d80-...                                        h1511 64gb
#
#                                                                     page_type  \
# http://dws.products.catalog/06b3b853-5246-4717-...  http://schema.org/Product
# http://dws.products.catalog/0bfe4eac-5a9c-4bb0-...  http://schema.org/Product
# http://dws.products.catalog/0fd9d78a-1ed6-4ed9-...  http://schema.org/Product
# http://dws.products.catalog/110d9912-96fd-4b0c-...  http://schema.org/Product
# http://dws.products.catalog/15ff8065-eb3b-4d80-...  http://schema.org/Product
#
#                                                    cat_package_height  \
# http://dws.products.catalog/06b3b853-5246-4717-...
# http://dws.products.catalog/0bfe4eac-5a9c-4bb0-...
# http://dws.products.catalog/0fd9d78a-1ed6-4ed9-...
# http://dws.products.catalog/110d9912-96fd-4b0c-...
# http://dws.products.catalog/15ff8065-eb3b-4d80-...
#
#                                                    cat_core_count  \
# http://dws.products.catalog/06b3b853-5246-4717-...
# http://dws.products.catalog/0bfe4eac-5a9c-4bb0-...
# http://dws.products.catalog/0fd9d78a-1ed6-4ed9-...
# http://dws.products.catalog/110d9912-96fd-4b0c-...           null
# http://dws.products.catalog/15ff8065-eb3b-4d80-...              8
#
#                                                    cat_phone_type cat_height  \
# http://dws.products.catalog/06b3b853-5246-4717-...       iphone 5     4.9 in
# http://dws.products.catalog/0bfe4eac-5a9c-4bb0-...      lumia 520     4.7 in
# http://dws.products.catalog/0fd9d78a-1ed6-4ed9-...      iphone 5s     4.9 in
# http://dws.products.catalog/110d9912-96fd-4b0c-...  iphone 6 plus     6.2 in
# http://dws.products.catalog/15ff8065-eb3b-4d80-...       nexus 6p    6.27 in
#
#                                                    cat_voltage  \
# http://dws.products.catalog/06b3b853-5246-4717-...
# http://dws.products.catalog/0bfe4eac-5a9c-4bb0-...
# http://dws.products.catalog/0fd9d78a-1ed6-4ed9-...   1560 mah
# http://dws.products.catalog/110d9912-96fd-4b0c-...    2915 mah
# http://dws.products.catalog/15ff8065-eb3b-4d80-...   3450 mah
#
#                                                    cat_display_resolution  \
# http://dws.products.catalog/06b3b853-5246-4717-...      1136 x 640 pixels
# http://dws.products.catalog/0bfe4eac-5a9c-4bb0-...       800 x 480 pixels
# http://dws.products.catalog/0fd9d78a-1ed6-4ed9-...      1136 x 640 pixels
# http://dws.products.catalog/110d9912-96fd-4b0c-...     1920 x 1080 pixels
# http://dws.products.catalog/15ff8065-eb3b-4d80-...     2560 x 1440 pixels
#
#                                                            cat_dimensions  \
# http://dws.products.catalog/06b3b853-5246-4717-...
# http://dws.products.catalog/0bfe4eac-5a9c-4bb0-...
# http://dws.products.catalog/0fd9d78a-1ed6-4ed9-...  123.8 x 58.6 x 7.6 mm
# http://dws.products.catalog/110d9912-96fd-4b0c-...  158.1 x 77.8 x 7.1 mm
# http://dws.products.catalog/15ff8065-eb3b-4d80-...  159.3 x 77.8 x 7.3 mm
#
#                                                    cat_memory  \
# http://dws.products.catalog/06b3b853-5246-4717-...       32gb
# http://dws.products.catalog/0bfe4eac-5a9c-4bb0-...        8gb
# http://dws.products.catalog/0fd9d78a-1ed6-4ed9-...       32gb
# http://dws.products.catalog/110d9912-96fd-4b0c-...      128gb
# http://dws.products.catalog/15ff8065-eb3b-4d80-...       64gb
#
#                                                                     ...                   \
# http://dws.products.catalog/06b3b853-5246-4717-...                  ...
# http://dws.products.catalog/0bfe4eac-5a9c-4bb0-...                  ...
# http://dws.products.catalog/0fd9d78a-1ed6-4ed9-...                  ...
# http://dws.products.catalog/110d9912-96fd-4b0c-...                  ...
# http://dws.products.catalog/15ff8065-eb3b-4d80-...                  ...
#
#                                                    cat_ram cat_display_size  \
# http://dws.products.catalog/06b3b853-5246-4717-...   512mb             4 in
# http://dws.products.catalog/0bfe4eac-5a9c-4bb0-...   512mb             4 in
# http://dws.products.catalog/0fd9d78a-1ed6-4ed9-...   512mb             4 in
# http://dws.products.catalog/110d9912-96fd-4b0c-...     1gb           5.5 in
# http://dws.products.catalog/15ff8065-eb3b-4d80-...     3gb           5.7 in
#
#                                                    cat_rear_cam_resolution  \
# http://dws.products.catalog/06b3b853-5246-4717-...                    8 mp
# http://dws.products.catalog/0bfe4eac-5a9c-4bb0-...                    5 mp
# http://dws.products.catalog/0fd9d78a-1ed6-4ed9-...                    8 mp
# http://dws.products.catalog/110d9912-96fd-4b0c-...                    8 mp
# http://dws.products.catalog/15ff8065-eb3b-4d80-...                 12.3 mp
#
#                                                    cat_modelnum cat_weight  \
# http://dws.products.catalog/06b3b853-5246-4717-...                    4 oz
# http://dws.products.catalog/0bfe4eac-5a9c-4bb0-...                  4.4 oz
# http://dws.products.catalog/0fd9d78a-1ed6-4ed9-...                 3.95 oz
# http://dws.products.catalog/110d9912-96fd-4b0c-...                 6.07 oz
# http://dws.products.catalog/15ff8065-eb3b-4d80-...                 6.28 oz
#
#                                                    cat_phone_carrier  \
# http://dws.products.catalog/06b3b853-5246-4717-...
# http://dws.products.catalog/0bfe4eac-5a9c-4bb0-...     not specified
# http://dws.products.catalog/0fd9d78a-1ed6-4ed9-...
# http://dws.products.catalog/110d9912-96fd-4b0c-...  verizon wireless
# http://dws.products.catalog/15ff8065-eb3b-4d80-...
#
#                                                    cat_width cat_brand  \
# http://dws.products.catalog/06b3b853-5246-4717-...    2.3 in     apple
# http://dws.products.catalog/0bfe4eac-5a9c-4bb0-...    2.5 in     nokia
# http://dws.products.catalog/0fd9d78a-1ed6-4ed9-...    2.3 in     apple
# http://dws.products.catalog/110d9912-96fd-4b0c-...    3.1 in     apple
# http://dws.products.catalog/15ff8065-eb3b-4d80-...   3.06 in    huawei
#
#                                                    cat_front_cam_resolution  \
# http://dws.products.catalog/06b3b853-5246-4717-...
# http://dws.products.catalog/0bfe4eac-5a9c-4bb0-...
# http://dws.products.catalog/0fd9d78a-1ed6-4ed9-...                   1.2 mp
# http://dws.products.catalog/110d9912-96fd-4b0c-...                   1.2 mp
# http://dws.products.catalog/15ff8065-eb3b-4d80-...                     8 mp
#
#                                                                               catalog_id
# http://dws.products.catalog/06b3b853-5246-4717-...  06b3b853-5246-4717-afed-4b40f94430ac
# http://dws.products.catalog/0bfe4eac-5a9c-4bb0-...  0bfe4eac-5a9c-4bb0-8a04-74f856e148c9
# http://dws.products.catalog/0fd9d78a-1ed6-4ed9-...  0fd9d78a-1ed6-4ed9-aa5b-82d49761a26b
# http://dws.products.catalog/110d9912-96fd-4b0c-...  110d9912-96fd-4b0c-a95f-cf61b2adb406
# http://dws.products.catalog/15ff8065-eb3b-4d80-...  15ff8065-eb3b-4d80-917d-28f5b7c8fa4e
#
# [5 rows x 31 columns]

# %%
gold_df=get_goldstandard(phone_path)
print(gold_df.shape)
gold_df.head()
# Out:
# (24999, 3)
#                             id_webpage              catalog_id  match
# 0  node5fd6d025f29b89ff319c853d0e33744           iphone 6 64gb      0
# 1  node5fd6d025f29b89ff319c853d0e33744     iphone 6 plus 128gb      0
# 2  node5fd6d025f29b89ff319c853d0e33744           iphone 4 16gb      0
# 3  node5fd6d025f29b89ff319c853d0e33744           iphone 4 32gb      0
# 4  node5fd6d025f29b89ff319c853d0e33744  samsung galaxy s6 32gb      0

# %%
gold_df['id_webpage'].nunique()
# Out:
# 500

# %%
gold_df['catalog_id'].nunique()
# Out:
# 50

# %%
webpage_check=gold_df[['id_webpage','match']].groupby('id_webpage')[['match']].sum()
print(webpage_check[webpage_check['match']==1].count())
print(webpage_check[webpage_check['match']==0].count())
# Out:
# match    221
# dtype: int64
# match    279
# dtype: int64

# %%
webpage_check
# Out:
#                                       match
# id_webpage
# node031213ef8e26298cc43dd6282ead2a3       1
# node0643f1b1f12ba371f0d1fc4c9645e         1
# node06edc149e3ceee41df94b232bcb80         1
# node0838278be7fc8b21449e123b6effce6       1
# node0998e335ef295a25624b8ca3a591d1        1
# node0c2bd1cb6738de050f1b6e15116416d       1
# node0c8b35393794b7e9da0f2ad0de2f71        1
# node0d8a2c18d36660a9ff23edbc57142         1
# node0f225b693af3a636e96933fb5591b3        1
# node102cd6767c8443e43c59b5522f3fc426      0
# node106072b227221966b7e25b5579973bd       0
# node10ae61df6f3aa66b81ac8675d289d48       0
# node10bd378eb979ad2a481765ceecbbd3c       1
# node10c7819e1cb4bea3ec9107df0dbc58a       0
# node10c99030eacaf324fb3ef94d7e4617c       1
# node10f44dbf33a99441412b4aa10d7a581       0
# node111bd3c99bde886558d1161796ae5         1
# node11aa9bdd13d58297e1d979f22e02b68       0
# node11ae9b11c6c5de168331c08ff93993        1
# node11d14387c08aa87e2e5a1f3c657032        1
# node11ec5d3fdac15db6a6316d065d62b16       0
# node11f04007cd0f5dcb2629412dc53fb27       1
# node11f21f83c41b35fedb3683d4dbeb9aa2      0
# node1218aa59223db7ad71a71d82578f14        1
# node1229217732928ddc23f59b16124547ec      1
# node12482a1f5f9545224c2811eab336626       1
# node126bb5fb80a9fc2c75327297daa97c4       0
# node127a86b7559f06c64a63e6afac6619e       1
# node129ecaaf6c73f6771f7675faaac39fd3      1
# node12b450a88f0d6b897758f676414c61        1
# ...                                     ...
# nodee2ca12db22c16f6d7cc9c2d15ab           1
# nodee4d4a3f22ab13c7c9e4ea3279fc0fc67      0
# nodee4e7a2817551f6487e17d6873261ae7       1
# nodee56666dce88a09814c7eeec523c6273       1
# nodee7695f362ecb33962e6a3cc57df1fcdc      0
# nodee7d46967476fccb37ed6df47922ebce       1
# nodee986524880bf70544e4cabe56766a8b6      1
# nodee9affe60fbe185b64feb5811d2e43159      1
# nodeea7a91219bc1ad66eae7f85761a85066      0
# nodeeb8a1fd3c53dff29e879d59c255359        1
# nodeeb9ab6329baec23bb20259374c24ea6       0
# nodeec80545e4e5e91a7bcb83e77092d9b4       0
# nodeedc6eb5745b490d92a8583e48533c84e      1
# nodeeea2f969ddce401fecb1f2eaec4a8cc       1
# nodeeee1d5b23a8fce6c28b3f6c0eb4a65        1
# nodeeef8b7661dbb5cfde430676c2bb3ec53      1
# nodef0ced9e4e998d84a91147a4ed92be         1
# nodef2e03616995fe9b116a9bac82e207d4b      0
# nodef356614f8ecfb8fd33bac8b24fd6e1        0
# nodef416ac516bfdc20c4efa61f35a04cdb       1
# nodef8766e598a76cc799e13bbce9d2e8a2       1
# nodef8ad5ee0be82c8b8356034bd5443702d      1
# nodef9c2495474b9c4a4ee3dcd4114d1521       0
# nodefb8d10de60d36162e38c809874d7e96b      1
# nodefbe92d8d707f4890495bd3ec44204e8c      1
# nodefc31b5e0622922f243defd23731c297b      0
# nodefe8bc8492cbd4861b5046bcd3ea83bd       0
# nodeff5d325a6de23ad0be494275a22e060       0
# nodeff9762bc5da41d1ab3c3bd6c36401240      0
# nodeffa8f4040d01e137ff1296e194c81d4       1
#
# [500 rows x 1 columns]

# %%
product_check=gold_df[['catalog_id','match']].groupby('catalog_id')[['match']].sum()
print(product_check[product_check['match']==1].count())
print(product_check[product_check['match']==0].count())
# Out:
# match    5
# dtype: int64
# match    20
# dtype: int64

# %%
product_check
# Out:
#                               match
# catalog_id
# htc one m8                       17
# htc one m9                       42
# htc one s                         0
# htc one v                         0
# htc one x                         2
# iphone 4 16gb                     4
# iphone 4 32gb                     0
# iphone 4s 16gb                   15
# iphone 4s 64gb                    0
# iphone 4s 8gb                     3
# iphone 5 16gb                     1
# iphone 5 32gb                     3
# iphone 5c 32gb                    1
# iphone 5s 16gb                    7
# iphone 5s 32gb                    4
# iphone 6 16gb                    15
# iphone 6 64gb                     6
# iphone 6 plus 128gb               1
# lg g4                             0
# lg g5                             0
# nexus 5 16gb                      0
# nexus 5 32gb                      0
# nexus 6p 128gb                    2
# nexus 6p 32gb                     3
# nexus 6p 64gb                    21
# nokia lumia 1020                  0
# nokia lumia 520                   5
# nokia lumia 521                   0
# nokia lumia 530                   1
# nokia lumia 635                   5
# nokia lumia 820                   0
# nokia lumia 900                   0
# nokia lumia 920                   4
# nokia lumia 925                   0
# samsung galaxy s4 16gb            4
# samsung galaxy s4 32gb            0
# samsung galaxy s4 mini 16gb       1
# samsung galaxy s5 16gb            2
# samsung galaxy s5 mini 16gb       0
# samsung galaxy s6 32gb            8
# samsung galaxy s6 edge 128gb      3
# samsung galaxy s6 edge 32gb      14
# samsung galaxy s6 edge 64gb       8
# samsung galaxy s6 edge+          10
# sony xperia c5 ultra              0
# sony xperia z                     0
# sony xperia z3                    0
# sony xperia z3 compact            0
# sony xperia z5 aqua               0
# sony xperia z5 premium            9

# %%
phone_path ='/Users/bengikoseoglu/Documents/Masters/Semester4/Thesis/Dataset/Phone'
phone_result=get_dataset(phone_path)
phone_result.to_csv('phone_merged.csv')
phone_result.head()
# Out:
# Product catalog shape (target): (50, 31)
# Product catalog after merging with extracted: (50, 33)
# Gold standard shape: (24999, 3)
# Product pages shape (source): (447, 29)
# Merge 1- web pages: (22349, 32)
# Merge 2- all: (21455, 60)
# Number of unique products from prodcat: 48
# Number of unique webpages: 447
# Matches:
# 0    21237
# 1      218
# Name: match, dtype: int64
#                              id_webpage  match  \
# 0   node5fd6d025f29b89ff319c853d0e33744      0
# 1  nodee9affe60fbe185b64feb5811d2e43159      0
# 2  nodeb1d0ceb9797fd339c5f7c04aa76a7af1      0
# 3    node12b450a88f0d6b897758f676414c61      0
# 4    node9ace9d5daf49116fed3f11241dff6d      0
#
#                                 page_mpn             page_warc  \
# 0                                    NaN  ebay.com0.warc.nq.gz
# 1                             htc6535lvw  ebay.com0.warc.nq.gz
# 2                                  6735a  ebay.com0.warc.nq.gz
# 3                                opja120  ebay.com0.warc.nq.gz
# 4  ebay_htconem932gbgoldonsilverunlocked  ebay.com0.warc.nq.gz
#
#        page_color                                           page_url  \
# 0  gold on silver  http://www.ebay.com/itm/blocked-htc-one-m9-32g...
# 1   gunmetal gray  http://www.ebay.com/itm/works-perfect-htc-one-...
# 2   gunmetal gray  http://www.ebay.com/itm/unlocked-htc-one-m9-32...
# 3            gold  http://www.ebay.com/itm/refurbished-htc-one-m9...
# 4  gold on silver  http://www.ebay.com/itm/nice-factory-unlocked-...
#
#   page_phone_type page_brand page_product_type page_rear_cam_resolution  \
# 0          one m9        htc        smartphone                   20.0mp
# 1              m9        htc        smartphone                    20 mp
# 2          one m9        htc        smartphone                    20 mp
# 3          one m9        htc               NaN                      NaN
# 4          one m9        htc        smartphone                    20 mp
#
#                    ...                  cat_modelnum cat_display_size  \
# 0                  ...                                         4.7 in
# 1                  ...                                         4.7 in
# 2                  ...                                         4.7 in
# 3                  ...                                         4.7 in
# 4                  ...                                         4.7 in
#
#   cat_width cat_product_type       cat_dimensions cat_front_cam_resolution  \
# 0    2.6 in       smartphone  138.1 x 67 x 6.9 mm                   1.2 mp
# 1    2.6 in       smartphone  138.1 x 67 x 6.9 mm                   1.2 mp
# 2    2.6 in       smartphone  138.1 x 67 x 6.9 mm                   1.2 mp
# 3    2.6 in       smartphone  138.1 x 67 x 6.9 mm                   1.2 mp
# 4    2.6 in       smartphone  138.1 x 67 x 6.9 mm                   1.2 mp
#
#                 cat_color prodcat_product_name  \
# 0  space gray|silver|gold        iphone 6 64gb
# 1  space gray|silver|gold        iphone 6 64gb
# 2  space gray|silver|gold        iphone 6 64gb
# 3  space gray|silver|gold        iphone 6 64gb
# 4  space gray|silver|gold        iphone 6 64gb
#
#                              prodcat_id                                    id
# 0  a7b16fc1-3a7d-4265-b4a6-a1a1cd548b80  db717f68-7a42-11e9-a70d-9a0011fd23e0
# 1  a7b16fc1-3a7d-4265-b4a6-a1a1cd548b80  db7181f2-7a42-11e9-a70d-9a0011fd23e0
# 2  a7b16fc1-3a7d-4265-b4a6-a1a1cd548b80  db71829c-7a42-11e9-a70d-9a0011fd23e0
# 3  a7b16fc1-3a7d-4265-b4a6-a1a1cd548b80  db7182d8-7a42-11e9-a70d-9a0011fd23e0
# 4  a7b16fc1-3a7d-4265-b4a6-a1a1cd548b80  db71830a-7a42-11e9-a70d-9a0011fd23e0
#
# [5 rows x 61 columns]

# %%
hp_result.head()
# Out:
# Product catalog shape (target): (51, 39)
# Product catalog after merging with extracted: (51, 41)
# Gold standard shape: (25499, 3)
# Product pages shape (source): (444, 30)
# Merge 1- web pages: (22643, 33)
# Merge 2- all: (23087, 69)
# Number of unique products from prodcat: 50
# Number of unique webpages: 444
# Matches:
# 0    22823
# 1      264
# Name: match, dtype: int64
#                              id_webpage  match page_headphones_form_factor  \
# 0     node449b610bd3ad6439d1b26190266d5      0      ear-cup (over the ear)
# 1  node4b4dee215b51f2eb45a114409ce7eda6      0      ear-cup (over the ear)
# 2    node52a9f6bc8fa1772a0f6a2832641fa1      0                         NaN
# 3  node6d72a28b4e6d7d1aff11ebab95221fa1      0      ear-cup (over the ear)
# 4     node88b5b595637fff2942878d19b2358      0                         NaN
#
#          page_mpn page_product_gtin             page_warc page_color  \
# 0  does not apply    does not apply  ebay.com0.warc.nq.gz      black
# 1  does not apply    does not apply  ebay.com0.warc.nq.gz      black
# 2  does not apply    does not apply  ebay.com0.warc.nq.gz        NaN
# 3  does not apply    does not apply  ebay.com0.warc.nq.gz      black
# 4  does not apply    does not apply  ebay.com0.warc.nq.gz        NaN
#
#   page_brand page_model                                           page_url  \
# 0        akg   k712 pro  http://www.ebay.com/itm/brand-new-akg-k712-pro...
# 1        akg   k712 pro  http://www.ebay.com/itm/brand-new-akg-k712-pro...
# 2        akg   k712 pro  http://www.ebay.com/itm/brand-new-akg-k712-pro...
# 3        akg   k712 pro  http://www.ebay.com/itm/brand-new-akg-k712-pro...
# 4        akg        NaN  http://www.ebay.com/itm/brand-new-akg-k712-pro...
#
#                    ...                  cat_sound_output_mode cat_sensitivity  \
# 0                  ...                                 stereo           99 db
# 1                  ...                                 stereo           99 db
# 2                  ...                                 stereo           99 db
# 3                  ...                                 stereo           99 db
# 4                  ...                                 stereo           99 db
#
#   cat_color cat_microphone_audio_details cat_headphones_cup_type  \
# 0     black                          n/a                  closed
# 1     black                          n/a                  closed
# 2     black                          n/a                  closed
# 3     black                          n/a                  closed
# 4     black                          n/a                  closed
#
#   cat_aditional_features cat_mdoel     prodcat_product_name  \
# 0                    NaN       NaN  audio technica ath-m50x
# 1                    NaN       NaN  audio technica ath-m50x
# 2                    NaN       NaN  audio technica ath-m50x
# 3                    NaN       NaN  audio technica ath-m50x
# 4                    NaN       NaN  audio technica ath-m50x
#
#                              prodcat_id                                    id
# 0  d7130c90-df60-4e0d-a898-ad8e2821dc7f  fa07e48a-7a42-11e9-a70d-9a0011fd23e0
# 1  d7130c90-df60-4e0d-a898-ad8e2821dc7f  fa07e5f2-7a42-11e9-a70d-9a0011fd23e0
# 2  d7130c90-df60-4e0d-a898-ad8e2821dc7f  fa07e656-7a42-11e9-a70d-9a0011fd23e0
# 3  d7130c90-df60-4e0d-a898-ad8e2821dc7f  fa07e69c-7a42-11e9-a70d-9a0011fd23e0
# 4  d7130c90-df60-4e0d-a898-ad8e2821dc7f  fa07e6d8-7a42-11e9-a70d-9a0011fd23e0
#
# [5 rows x 70 columns]

# %%
prod_cat=get_product_cat(hp_path)
gold=get_goldstandard(hp_path)
tv_result.to_csv('tv_merged.csv')
tv_result.head()
# Out:
# Product catalog shape (target): (60, 78)
# Product catalog after merging with extracted: (60, 80)
# Gold standard shape: (29999, 3)
# Product pages shape (source): (428, 479)
# Merge 1- web pages: (25679, 482)
# Merge 2- all: (25679, 556)
# Number of unique products from prodcat: 60
# Number of unique webpages: 428
# Matches:
# 0    25495
# 1      184
# Name: match, dtype: int64
#                              id_webpage  match page_closed_captions_(cc)  \
# 0  node2adaa221ac4791c47f29f345972f1c91      0                       NaN
# 1   nodeb452c577135dea4d89c4fcd40b9ac4f      0                       NaN
# 2  nodef741bd19171e3c5f35e514b43c112972      0                       NaN
# 3  node62aa28f37676c392289b6393a7a550e8      0                       NaN
# 4   node66e1a3264db98d4cab3dbe4f9295858      0                       NaN
#
#   page_subwoofer_out page_dimming_type page_auto_photo_mode page_mhl  \
# 0                NaN               NaN                  NaN      NaN
# 1                NaN               NaN                  NaN      NaN
# 2                NaN               NaN                  NaN      NaN
# 3                NaN               NaN                  NaN      NaN
# 4                NaN               NaN                  NaN      NaN
#
#   page_5.1_channel_audio_out page_wi-fi_standard  \
# 0                        NaN                 NaN
# 1                        NaN                 NaN
# 2                        NaN                 NaN
# 3                        NaN                 NaN
# 4                        NaN                 NaN
#
#   page_composite_video_input(s)                  ...                   \
# 0                           NaN                  ...
# 1                           NaN                  ...
# 2                           NaN                  ...
# 3                           NaN                  ...
# 4                           NaN                  ...
#
#   cat_timer_functions cat_input_video_formats cat_memory cat_brightness  \
# 0
# 1
# 2
# 3
# 4
#
#   cat_color cat_speakers_qty cat_3d_technology prodcat_product_name  \
# 0                          2           passive          lg 55eg9600
# 1                          2           passive          lg 55eg9600
# 2                          2           passive          lg 55eg9600
# 3                          2           passive          lg 55eg9600
# 4                          2           passive          lg 55eg9600
#
#                              prodcat_id                                    id
# 0  84e2838d-a419-4a5b-a284-9463b01cea52  fd165238-7a42-11e9-a70d-9a0011fd23e0
# 1  84e2838d-a419-4a5b-a284-9463b01cea52  fd16536e-7a42-11e9-a70d-9a0011fd23e0
# 2  84e2838d-a419-4a5b-a284-9463b01cea52  fd1653d2-7a42-11e9-a70d-9a0011fd23e0
# 3  84e2838d-a419-4a5b-a284-9463b01cea52  fd165418-7a42-11e9-a70d-9a0011fd23e0
# 4  84e2838d-a419-4a5b-a284-9463b01cea52  fd16545e-7a42-11e9-a70d-9a0011fd23e0
#
# [5 rows x 557 columns]

# %%
prod_cat=get_product_cat(tv_path)
gold=get_goldstandard(tv_path)
print(set(prod_cat['prodcat_product_name'].unique())- set(tv_result['prodcat_product_name'].unique()))
print(set(gold['id_webpage'].unique())- set(tv_result['id_webpage'].unique()))
# Out:
# set()
# {'node3ff0b1197849cb836a92b727b558f', 'node57c878704a407a1da0d18b17ce9e0fa', 'nodee3a0d88b28c16768f5b2dff1e2bb813', 'nodeabc4a961b7c7cd47dbb53c6f907c65', 'node3fccecec87624cfea7cfa8f596356d0', 'nodefa27dc9d8eb1ba24b36c6c585ace7ce', 'node922c412f1611baaed3fd56ad96cfc619', 'nodee4dd2d090fce8371076b168ab3ce6e3', 'node2b6cda69d3fec